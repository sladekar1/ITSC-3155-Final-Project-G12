# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import data
data=pd.read_csv("oscars_df.csv")

#Check what columns we have to decide wht we will use
pd.set_option("display.max.columns", None)
data.head(5)
# Out:
#    Unnamed: 0                 Film Oscar Year Film Studio/Producer(s)  \
# 0           0                Wings    1927/28    Famous Players-Lasky
# 1           1           7th Heaven    1927/28                     Fox
# 2           2           The Racket    1927/28       The Caddo Company
# 3           3  The Broadway Melody    1928/29     Metro-Goldwyn-Mayer
# 4           4                Alibi    1928/29     Feature Productions
#
#      Award  Year of Release  Movie Time            Movie Genre  IMDB Rating  \
# 0   Winner             1927         144      Drama,Romance,War          7.5
# 1  Nominee             1927         110          Drama,Romance          7.7
# 2  Nominee             1928          84  Crime,Drama,Film-Noir          6.7
# 3   Winner             1929         100  Drama,Musical,Romance          5.7
# 4  Nominee             1929          91   Action,Crime,Romance          5.8
#
#   IMDB Votes                                         Movie Info  \
# ...

# %%
#some columns repit each other and some columns will not be useful for our app
# create copy of original dataset
data_new = data.copy()
# drop column we will not use
data_new.drop(["Unnamed: 0",'Oscar Year', 'IMDB Votes', "Genres",  "Authors", "Original Release Date", "Production Company", "Tomatometer Count",
              "Audience Count", "Tomatometer Top Critics Count", "Tomatometer Fresh Critics Count",  "Tomatometer Rotten Critics Count"], axis=1, inplace= True)
data_new.head(5)
# Out:
#                   Film Film Studio/Producer(s)    Award  Year of Release  \
# 0                Wings    Famous Players-Lasky   Winner             1927
# 1           7th Heaven                     Fox  Nominee             1927
# 2           The Racket       The Caddo Company  Nominee             1928
# 3  The Broadway Melody     Metro-Goldwyn-Mayer   Winner             1929
# 4                Alibi     Feature Productions  Nominee             1929
#
#    Movie Time            Movie Genre  IMDB Rating  \
# 0         144      Drama,Romance,War          7.5
# 1         110          Drama,Romance          7.7
# 2          84  Crime,Drama,Film-Noir          6.7
# 3         100  Drama,Musical,Romance          5.7
# 4          91   Action,Crime,Romance          5.8
#
#                                           Movie Info  \
# 0  With World War I afoot, David Armstrong (Richa...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Film                     571 non-null    object
#  1   Film Studio/Producer(s)  571 non-null    object
#  2   Award                    571 non-null    object
#  3   Year of Release          571 non-null    int64
#  4   Movie Time               571 non-null    int64
#  5   Movie Genre              571 non-null    object
#  6   IMDB Rating              571 non-null    float64
#  7   Movie Info               438 non-null    object
#  8   Critic Consensus         339 non-null    object
#  9   Content Rating           439 non-null    object
#  10  Directors                437 non-null    object
#  11  Actors                   439 non-null    object
#  12  Streaming Release Date   438 non-null    object
#  13  Tomatometer Status       439 non-null    object
# ...

# %%
# drop row with NaN value
data_new.dropna(axis=0, how='any', inplace=False)
# Out:
#                     Film                            Film Studio/Producer(s)  \
# 0                  Wings                               Famous Players-Lasky
# 3    The Broadway Melody                                Metro-Goldwyn-Mayer
# 13              Cimarron                                          RKO Radio
# 18           Grand Hotel                                Metro-Goldwyn-Mayer
# 26             Cavalcade                                                Fox
# ..                   ...                                                ...
# 549    Bohemian Rhapsody                                        Graham King
# 550        The Favourite  Ceci Dempsey, Ed Guiney, Lee Magiday, and Yorg...
# 551                 Roma              Gabriela Rodríguez and Alfonso Cuarón
# 552       A Star Is Born  Bill Gerber, Bradley Cooper, and Lynette Howel...
# 553                 Vice  Dede Gardner, Jeremy Kleiner, Adam McKay, and ...
#
# ...

# %%
# create new clean *.csv file
data_new.to_csv ("oscar_clean.csv")
